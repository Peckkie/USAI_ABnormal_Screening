# %%
import os
import numpy as np
import pandas as pd
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FeaturesVector_train.csv')
dataframe
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0              0 -0.040543 -0.056497 -0.102460 -0.116914  0.003635 -0.118240
# 1              1 -0.085599 -0.132821 -0.176368 -0.101640 -0.186999 -0.099913
# 2              2 -0.085500 -0.107692 -0.155854  0.099468 -0.077141 -0.118573
# 3              3 -0.076597 -0.107777 -0.056727 -0.065636 -0.097833 -0.127306
# 4              4 -0.103560 -0.120132 -0.023788 -0.097609 -0.187480 -0.135415
# 5              5 -0.062576 -0.091727 -0.164792 -0.091197 -0.005163  0.091629
# 6              6  0.043055 -0.081453 -0.152424  0.319677  0.515873 -0.108686
# 7              7 -0.058352 -0.141001 -0.139918  0.186003  0.662511 -0.113037
# 8              8  0.123420 -0.080800  0.080010  0.353328  0.178444  0.655232
# 9              9 -0.122150  0.611730 -0.162709  0.138139  0.408210 -0.027958
# 10            10 -0.030638 -0.094323 -0.191327  0.433427  0.498691 -0.137470
# 11            11 -0.129565 -0.145180 -0.163787 -0.010848  0.236715 -0.052309
# 12            12 -0.057243 -0.077255 -0.108110  0.058251  0.344157 -0.080376
# 13            13  0.304165 -0.077896 -0.023425 -0.122460  0.217885 -0.136453
# 14            14 -0.059318  0.273597 -0.050239 -0.054121  0.157870 -0.151184
# 15            15 -0.027646 -0.074239 -0.115294 -0.089290  0.276253 -0.139132
# 16            16 -0.138744  0.194348 -0.184936 -0.106116 -0.075212 -0.125681
# 17            17 -0.084203  0.013669  0.129537  0.104994  0.272275  0.054011
# 18            18 -0.087587  0.060244 -0.114548 -0.165415 -0.076204 -0.028867
# 19            19  0.061352 -0.158040 -0.069291  0.040477 -0.120434 -0.091398
# 20            20 -0.062351 -0.050885 -0.138263  0.084512 -0.172588 -0.105144
# 21            21  0.011543 -0.127951  0.036130  0.147580 -0.096414  0.055604
# 22            22 -0.046612 -0.119154 -0.112626  0.306901 -0.142016 -0.089464
# 23            23  0.061360  0.118214 -0.123075  0.017171  0.075170 -0.105803
# 24            24 -0.126180 -0.028011 -0.142812 -0.006737  0.102168 -0.092885
# 25            25 -0.060687 -0.008972 -0.094809  0.089647 -0.189025 -0.134566
# 26            26 -0.016874 -0.103581 -0.122408 -0.047744 -0.216342 -0.110795
# 27            27  0.060950 -0.103597 -0.123388 -0.150706  0.016874 -0.085505
# 28            28 -0.122192 -0.141800 -0.007013 -0.091553 -0.032509 -0.031265
# 29            29  0.016647 -0.070351 -0.130430 -0.121696 -0.171259 -0.135626
# ...          ...       ...       ...       ...       ...       ...       ...
# 4542        4542  0.531226 -0.124362 -0.104386  0.100201  0.155093 -0.105928
# 4543        4543  0.101358 -0.083069 -0.039087 -0.130756 -0.032549 -0.118484
# 4544        4544  0.013311  0.451771 -0.063707 -0.163111 -0.141161  0.404089
# 4545        4545  0.412583 -0.052139  0.195119  0.022281  0.071872  0.435172
# 4546        4546 -0.080827 -0.132986 -0.175483 -0.132007  0.002254  0.629140
# 4547        4547  0.062488  0.438698 -0.147951 -0.115855 -0.088738  0.494419
# 4548        4548 -0.048375  0.003041 -0.138046  0.106925  0.049926 -0.118793
# 4566  0.328395 -0.141190 -0.005770  ... -0.122783 -0.094325  0.207969
# 4567 -0.164573 -0.103270  0.169248  ... -0.013530 -0.068126  0.192480
# 4568 -0.155863 -0.096222 -0.173687  ... -0.115571 -0.214937 -0.137983
# 4569 -0.050075 -0.151513 -0.132238  ... -0.161207 -0.101741  0.049496
# 4570 -0.055382 -0.106493  0.030313  ... -0.149111  0.023984 -0.123226
# 4571 -0.128851  0.144003  0.212958  ...  0.205546  0.054452 -0.114606
#
#           1276      1277      1278      1279     Class  SubPosition  Views
# 0    -0.025618 -0.138402 -0.149828 -0.058487  Abnormal          P52   FP-C
# 1     0.271841 -0.100678 -0.173985 -0.140239  Abnormal           P1   FP-A
# 2     0.107301 -0.111334 -0.211983 -0.084865  Abnormal           P2   FP-A
# 3     0.106516 -0.120817 -0.113517 -0.024973  Abnormal          P51   FP-C
# 4     0.015327 -0.133074 -0.061550 -0.140919  Abnormal          P42   FP-B
# 5    -0.186481 -0.101489 -0.062740  0.015151  Abnormal          P41   FP-B
# 6     0.831290 -0.020020  0.274728 -0.025482  Abnormal           P1   FP-A
# 7     0.264159 -0.108425  0.237728 -0.114794  Abnormal           P2   FP-A
# 8     0.616245  0.064519  0.376250 -0.093924  Abnormal          P31   FP-B
# 9     0.223190  0.237468  1.214644  0.099624  Abnormal           P2   FP-A
# 10    0.090033 -0.018554  0.892704  0.010276  Abnormal           P1   FP-A
# 11    0.060955 -0.087692  0.297474 -0.108635  Abnormal          P41   FP-B
# 12    0.121526 -0.026248  0.672591 -0.126140  Abnormal          P51   FP-C
# 13   -0.060738 -0.117834  0.026175  0.158245  Abnormal          P61   FP-C
# 14   -0.025168  0.008744 -0.118603 -0.006660  Abnormal          P41   FP-B
# 15   -0.099900 -0.120828  0.559982 -0.026836  Abnormal          P51   FP-C
# 16   -0.144877 -0.105588  0.033477 -0.075820  Abnormal          P51   FP-C
# 17    0.035224 -0.078427 -0.006133  0.014109  Abnormal          P61   FP-C
# 18   -0.121336  0.042716  0.082895 -0.110600  Abnormal          P52   FP-C
# 19    0.682519 -0.076960 -0.007710 -0.125614  Abnormal           P2   FP-A
# 20    0.020539  0.065687 -0.107582 -0.146779  Abnormal           P1   FP-A
# 21    0.715932 -0.047820 -0.111064  0.088660  Abnormal          P42   FP-B
# 22    0.381077 -0.118696 -0.148988 -0.076375  Abnormal          P31   FP-B
# 23   -0.099780  0.068028 -0.182739 -0.068504  Abnormal          P41   FP-B
# 24   -0.146300 -0.058251 -0.018701 -0.164119  Abnormal          P52   FP-C
# 25    0.085807 -0.125307 -0.105328 -0.075294  Abnormal          P51   FP-C
# 26    0.153447 -0.116751 -0.076745 -0.129981  Abnormal          P31   FP-B
# 27    0.633700 -0.111407 -0.119440 -0.142699  Abnormal           P2   FP-A
# 28    0.138247 -0.111304 -0.137413  0.081043  Abnormal          P51   FP-C
# 29    0.130245 -0.111618 -0.084584 -0.072439  Abnormal           P1   FP-A
# ...        ...       ...       ...       ...       ...          ...    ...
# 4542 -0.113834  0.091592 -0.117045 -0.072992    Normal          P72   FP-D
# 4543 -0.167774 -0.159936 -0.115531 -0.117595    Normal          P72   FP-D
# 4544 -0.164561  0.067826  0.092334 -0.127544    Normal          P72   FP-D
# 4545 -0.103181  0.542266 -0.102190  0.066721    Normal          P72   FP-D
# 4546  0.066869 -0.027699 -0.189557 -0.041704    Normal          P72   FP-D
# 4547 -0.087172  0.240224 -0.146873  0.039367    Normal          P72   FP-D
# 4548 -0.015575  0.047834  0.144362 -0.045119    Normal          P72   FP-D
# 4549 -0.148325  0.000318  0.436589 -0.013609    Normal          P72   FP-D
# 4550 -0.134690  0.090227  0.058674  0.195218    Normal          P72   FP-D
# 4551  0.005619  0.004421  0.017538 -0.159365    Normal          P72   FP-D
# 4552 -0.079097 -0.118846  0.191793 -0.115181    Normal          P72   FP-D
# 4553  0.128958  0.114589 -0.036285 -0.016441    Normal          P72   FP-D
# 4554 -0.085697  0.247433  0.757672 -0.143853    Normal          P72   FP-D
# 4555 -0.145358 -0.107955  0.076002 -0.106735    Normal          P72   FP-D
# 4556 -0.157274 -0.106598  0.067184 -0.183173    Normal          P72   FP-D
# 4557 -0.049019 -0.091707 -0.171702 -0.026529    Normal          P72   FP-D
# 4558  0.041098  0.455516  0.122659 -0.114387    Normal          P72   FP-D
# 4559  0.532984 -0.107306 -0.155911 -0.064556    Normal          P72   FP-D
# 4560 -0.149574  0.065580 -0.134225 -0.145437    Normal          P72   FP-D
# 4561 -0.120799 -0.059471  0.089555 -0.101541    Normal          P72   FP-D
# 4562 -0.164871 -0.157653 -0.096573 -0.014046    Normal          P72   FP-D
# 4563 -0.125324  0.018560 -0.081690  0.068434    Normal          P72   FP-D
# 4564 -0.161054 -0.075441  0.014523 -0.089401    Normal          P72   FP-D
# 4565 -0.122920  0.353378  0.070228  0.039821    Normal          P72   FP-D
# 4566 -0.038136  0.011665  0.074467 -0.188449    Normal          P72   FP-D
# 4567 -0.148398 -0.097330 -0.099094 -0.134845    Normal          P72   FP-D
# 4568  0.377962  0.141866  0.198920 -0.086991    Normal          P72   FP-D
# 4569 -0.118444  0.542218 -0.179448  0.176811    Normal          P72   FP-D
# 4570  0.106814 -0.083880 -0.072714 -0.141697    Normal          P72   FP-D
# 4571 -0.113674  0.145453 -0.130540 -0.059314    Normal          P72   FP-D
#
# [4572 rows x 1284 columns]

# %%
X = dataframe.iloc[:,1:1281]
y = dataframe.iloc[:,1283]
print(X.shape)
print(y.shape)
# Out:
# (4572, 1280)
# (4572,)

# %%
print(set(y))
# Out:
# {'FP-E', 'FP-D', 'FP-B', 'FP-A', 'FP-C'}

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier


n_estimators = [400]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100] 

forest = RandomForestClassifier(random_state = 1)


hyperF ={'n_estimators' : n_estimators, 'max_depth' : max_depth, 'min_samples_split' : min_samples_split}
# hyperF ={'max_depth' : max_depth, 'min_samples_split' : min_samples_split}

gridF = GridSearchCV(forest, hyperF, cv = 10, verbose = 1, n_jobs = -1)
bestF = gridF.fit(X, y)
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  6.4min finished

# %%
# view the results as a pandas DataFrame
import pandas as pd
pd.DataFrame(bestF.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#     mean_test_score  std_test_score  \
# 0          0.638885        0.065052
# 1          0.639540        0.065546
# 2          0.638884        0.059959
# 3          0.638448        0.062294
# 4          0.633637        0.063047
# 5          0.717635        0.057483
# 6          0.716323        0.057949
# 7          0.715011        0.059305
# 8          0.713479        0.064446
# 9          0.678259        0.064001
# 10         0.745415        0.050046
# 11         0.741481        0.053458
# 12         0.741255        0.043887
# 13         0.736446        0.056774
# 14         0.686792        0.062953
# 15         0.744978        0.050043
# 16         0.743008        0.046015
# 17         0.743445        0.048859
# 18         0.737325        0.051722
# 19         0.691167        0.062252
# 20         0.745852        0.048470
# 21         0.744976        0.046167
# 22         0.743883        0.049168
# 23         0.738418        0.051930
# 24         0.690073        0.062568
#
#                                                params
# 0   {'max_depth': 5, 'min_samples_split': 2, 'n_es...
# 1   {'max_depth': 5, 'min_samples_split': 5, 'n_es...
# 2   {'max_depth': 5, 'min_samples_split': 10, 'n_e...
# 3   {'max_depth': 5, 'min_samples_split': 15, 'n_e...
# 4   {'max_depth': 5, 'min_samples_split': 100, 'n_...
# 5   {'max_depth': 8, 'min_samples_split': 2, 'n_es...
# 6   {'max_depth': 8, 'min_samples_split': 5, 'n_es...
# 7   {'max_depth': 8, 'min_samples_split': 10, 'n_e...
# 8   {'max_depth': 8, 'min_samples_split': 15, 'n_e...
# 9   {'max_depth': 8, 'min_samples_split': 100, 'n_...
# 10  {'max_depth': 15, 'min_samples_split': 2, 'n_e...
# 11  {'max_depth': 15, 'min_samples_split': 5, 'n_e...
# 12  {'max_depth': 15, 'min_samples_split': 10, 'n_...
# 13  {'max_depth': 15, 'min_samples_split': 15, 'n_...
# 14  {'max_depth': 15, 'min_samples_split': 100, 'n...
# 15  {'max_depth': 25, 'min_samples_split': 2, 'n_e...
# 16  {'max_depth': 25, 'min_samples_split': 5, 'n_e...
# 17  {'max_depth': 25, 'min_samples_split': 10, 'n_...
# 18  {'max_depth': 25, 'min_samples_split': 15, 'n_...
# 19  {'max_depth': 25, 'min_samples_split': 100, 'n...
# 20  {'max_depth': 30, 'min_samples_split': 2, 'n_e...
# 21  {'max_depth': 30, 'min_samples_split': 5, 'n_e...
# 22  {'max_depth': 30, 'min_samples_split': 10, 'n_...
# 23  {'max_depth': 30, 'min_samples_split': 15, 'n_...
# 24  {'max_depth': 30, 'min_samples_split': 100, 'n...

# %%
# examine the first result
print("**examine the first result","\n")

print(bestF.cv_results_['params'][0])
print(bestF.cv_results_['mean_test_score'][0])

# print the array of mean scores only
print("\n","**print the array of mean scores only","\n")

grid_mean_scores = bestF.cv_results_['mean_test_score']
print(grid_mean_scores)

# examine the best model
print("\n","**examine the best model","\n")

print(bestF.best_score_)
print(bestF.best_params_)
print(bestF.best_estimator_)
# Out:
# **examine the first result
#
# {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}
# 0.6388846951353522
#
#  **print the array of mean scores only
#
# [0.6388847  0.63953972 0.63888422 0.63844849 0.63363735 0.71763495
#  0.71632251 0.71501104 0.71347883 0.67825863 0.74541485 0.74148137
#  0.74125539 0.73644568 0.68679159 0.74497769 0.74300832 0.74344548
#  0.73732526 0.691167   0.74585248 0.74497578 0.74388264 0.73841791
#  0.69007339]
#
#  **examine the best model
#
# 0.74585248392306
# {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 400}
# RandomForestClassifier(max_depth=30, n_estimators=400, random_state=1)

# %%
#Print the tured parameters and score
print("Tuned Decision Tree Parameters: {}".format(bestF.best_params_))
print("Best score is {}".format(bestF.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 400}
# Best score is 0.74585248392306

# %%
forestOpt = RandomForestClassifier(random_state = 1, max_depth = 30, n_estimators = 400, min_samples_split =2)
             
modelOpt = forestOpt.fit(X, y)#

# %%
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FeaturesVector_val.csv')
X_test= dataframe.iloc[:,1:1281]
y_test = dataframe.iloc[:,1283]
print(X_test.shape)
print(y_test.shape)
# Out:
# (653, 1280)
# (653,)

# %%
y_pred = modelOpt.predict(X_test)

# %%
#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))#performance
# Out:
# [[ 93  21  11   3   1]
#  [ 16 161  12   4   3]
#  [  5  14 156  13   1]
#  [  3   3  18  82   0]
#  [  2   8   0   0  23]]
#               precision    recall  f1-score   support
#
#         FP-A       0.78      0.72      0.75       129
#         FP-B       0.78      0.82      0.80       196
#         FP-C       0.79      0.83      0.81       189
#         FP-D       0.80      0.77      0.79       106
#         FP-E       0.82      0.70      0.75        33
#
#     accuracy                           0.79       653
#    macro avg       0.80      0.77      0.78       653
# weighted avg       0.79      0.79      0.79       653

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)

import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %%
#create CF 
data = {'Actual': y_test,'Predicted' : y_pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %% [markdown]
# # Save Model

# %%
os.chdir('/media/tohn/SSD/ModelTrainByImage/R1/models')
# !ls
# Out:
# B0_R12_balance.h5  B3_R1.h5   IncepRNV2_R12.h5	   RF5FP_model.pkl
# B0_R12.h5	   B4_R12.h5  IncepRNV2_R1.h5	   RN101_R12.h5
# B0_R1_balance.h5   B4_R1.h5   IncepV3_R12.h5	   RN101_R1.h5
# B0_R1.h5	   B5_R12.h5  IncepV3_R1.h5	   RN101V2_R12.h5
# B1_R12.h5	   B5_R1.h5   NNL_R12.h5	   RN101V2_R1.h5
# B1_R1.h5	   B6_R12.h5  NNL_R1.h5		   RN502_R1.h5
# B2_R12.h5	   B6_R1.h5   NNM_R12.h5	   RN50_R12.h5
# B2_R1.h5	   B7_R12.h5  NNM_R1.h5		   RN50V22_R1.h5
# B3_R12.h5	   B7_R1.h5   RF13views_model.pkl  RN50V2_R12.h5

# %%
#Save Model

import pickle
os.chdir('/media/tohn/SSD/ModelTrainByImage/R1/models')
filename = "RF5FP_model.pkl"
with open(filename, 'wb') as file:
    pickle.dump(modelOpt, file)

# %%
#load model

with open(filename, 'rb') as file:
    model = pickle.load(file)
